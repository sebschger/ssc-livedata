# %%
from pathlib import Path
import os
import json
import requests

# %%
TESTFILE = "Raw test data.txt"

# %%
with open(TESTFILE) as file:
    raw_json_string = file.readlines()
    raw_json_string = "\n".join(raw_json_string)

print(raw_json_string)
# Out:
# {"end_device_ids": {"device_id": "lht65n-pir-001", "application_ids": {"application_id": "portfolio-environment-sensing"}, "dev_eui": "A8404162E45ADC61", "join_eui": "A840410000000100", "dev_addr": "260B4BA2"}, "correlation_ids": ["gs:uplink:01KK6MN3MZ5GVN317VH6VM83EM"], "received_at": "2026-03-08T11:52:21.610982394Z", "uplink_message": {"session_key_id": "AZyVGkaYsTAdPY84x4ZQUQ==", "f_port": 2, "f_cnt": 824, "frm_payload": "zB8DZwLBDgAAAn8=", "decoded_payload": {"BatV": 3.103, "Bat_status": 3, "Exti_pin_level": "No activity", "Hum_SHT": 70.5, "Move_count": 639, "Node_type": "LHT65N-PIR", "TempC_SHT": 8.71, "Work_mode": "PIR Sensor"}, "rx_metadata": [{"gateway_ids": {"gateway_id": "dragino-lg308-gaturatz", "eui": "A840411BB01C4150"}, "time": "2026-03-08T11:52:21.377510Z", "timestamp": 3038477524, "rssi": -105, "channel_rssi": -105, "snr": 6, "location": {"latitude": 48.15661926353526, "longitude": 11.536492109298708, "altitude": 540, "source": "SOURCE_REGISTRY"}, "uplink_token": "CiQ
# ...

# %%
json_data = json.loads(raw_json_string)

# %%
print(json.dumps(json_data, indent=4))
# Out:
# {
#     "end_device_ids": {
#         "device_id": "lht65n-pir-001",
#         "application_ids": {
#             "application_id": "portfolio-environment-sensing"
#         },
#         "dev_eui": "A8404162E45ADC61",
#         "join_eui": "A840410000000100",
#         "dev_addr": "260B4BA2"
#     },
#     "correlation_ids": [
#         "gs:uplink:01KK6MN3MZ5GVN317VH6VM83EM"
#     ],
#     "received_at": "2026-03-08T11:52:21.610982394Z",
#     "uplink_message": {
#         "session_key_id": "AZyVGkaYsTAdPY84x4ZQUQ==",
#         "f_port": 2,
#         "f_cnt": 824,
#         "frm_payload": "zB8DZwLBDgAAAn8=",
#         "decoded_payload": {
#             "BatV": 3.103,
#             "Bat_status": 3,
#             "Exti_pin_level": "No activity",
#             "Hum_SHT": 70.5,
#             "Move_count": 639,
#             "Node_type": "LHT65N-PIR",
#             "TempC_SHT": 8.71,
#             "Work_mode": "PIR Sensor"
#         },
#         "rx_metadata": [
#             {
# ...

# %%
requests.post(url="https://localhost:5001/sensor-data-pusher", json=json_data, headers={"Content-Type":"application/json", "Authentication" : "4z57iehkrj"})
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
requests.post(url="https://livedata.sebastianscharnagl.com/sensor-data-pusher/", json=json_data, headers={"Content-Type":"application/json", "authorization" : "xxxx"})
# Out:
# <Response [200]>
